# %% [markdown]
# <a href="https://colab.research.google.com/github/lima-12/estatistica-llm/blob/main/parte1A_histogramas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Primeira parte, fazer o histograma.
